# %%
import pandas as pd
import numpy as np

# %%
numeros = pd.Series([1,2,3,4,5])
numeros
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
numeros = pd.Series([1,2,3,4,5], index =['a','b','c','d','h'])
numeros
# Out:
# a    1
# b    2
# c    3
# d    4
# h    5
# dtype: int64

# %%
datos = {'a':1, 'b':2, 'c':3}
serie_dict = pd.Series(datos)
serie_dict
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
numeros['c']
# Out:
# np.int64(3)

# %%
numeros['a'] = 10

# %%
numeros
# Out:
# a    10
# b     2
# c     3
# d     4
# h     5
# dtype: int64

# %%
numeros**2
# Out:
# a    100
# b      4
# c      9
# d     16
# h     25
# dtype: int64

# %%
numeros+3
# Out:
# a    13
# b     5
# c     6
# d     7
# h     8
# dtype: int64

# %%
numeros.mean()
# Out:
# np.float64(4.8)

# %%
numeros.sum()
# Out:
# np.int64(24)

# %%
numeros.max()
# Out:
# np.int64(10)

# %%
numeros.min()
# Out:
# np.int64(2)

# %%
numeros[numeros <= 3]
# Out:
# b    2
# c    3
# dtype: int64

# %%
numeros.apply(np.log)
# Out:
# a    2.302585
# b    0.693147
# c    1.098612
# d    1.386294
# h    1.609438
# dtype: float64

# %%
nombres = pd.Series(['Jose', 'Pedro', 'Luis'])
edades = pd.Series([25,30,35])

df_personas = pd.DataFrame({'Nombre':nombres, 'Edad':edades})
df_personas
# Out:
#   Nombre  Edad
# 0   Jose    25
# 1  Pedro    30
# 2   Luis    35

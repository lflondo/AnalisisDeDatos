# %%
import pandas as pd

# %%
data = {
    'Producto':['Manzanas', 'Naranjas', 'Platanos', 'Uvas', 'Peras'],
    'Precio': [100, 80, 60, 120, 90],
    'Stock': [30, 50, 20, 60, 40]
}

df = pd.DataFrame(data)
df
# Out:
#    Producto  Precio  Stock
# 0  Manzanas     100     30
# 1  Naranjas      80     50
# 2  Platanos      60     20
# 3      Uvas     120     60
# 4     Peras      90     40

# %%
suma_precios = df['Precio'].sum()
print("Suma de precios:", suma_precios)
# Out:
# Suma de precios: 450

# %%
media_precios = df['Precio'].mean()
print("Media de precios: ", media_precios)
# Out:
# Media de precios:  90.0

# %%
media_precios = df['Precio'].median()
print("Media de precios: ", media_precios)
# Out:
# Media de precios:  90.0

# %%
min_precio = df['Precio'].min()
max_precio = df['Precio'].max()
print("Minimo precio:",min_precio)
print("Maximo precio:", max_precio)
# Out:
# Minimo precio: 60
# Maximo precio: 120

# %%
std_precio = df['Precio'].std()
var_precio = df['Precio'].var()
print("Desviacion estandar de precios:",std_precio)
print("Varianza de precios:", var_precio)
# Out:
# Desviacion estandar de precios: 22.360679774997898
# Varianza de precios: 500.0

# %%
cumsum_precios = df['Precio'].cumsum()
print(cumsum_precios)
# Out:
# 0    100
# 1    180
# 2    240
# 3    360
# 4    450
# Name: Precio, dtype: int64

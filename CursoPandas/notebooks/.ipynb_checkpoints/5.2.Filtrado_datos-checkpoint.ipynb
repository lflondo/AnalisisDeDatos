# %%
import pandas as pd
data = {
    'Producto':['Manzanas', 'Naranjas', 'Platanos', 'uvas', 'Peras'],
    'Precio': [100, 80, 60, 120, 90],
    'Stock':[30,50,20,30,40]
}
df = pd.DataFrame(data)
df
# Out:
#    Producto  Precio  Stock
# 0  Manzanas     100     30
# 1  Naranjas      80     50
# 2  Platanos      60     20
# 3      uvas     120     30
# 4     Peras      90     40

# %%
filtro_precio = df[df['Precio']>80]
print("Productos con precio mayor a 80:\n", filtro_precio)
# Out:
# Productos con precio mayor a 80:
#     Producto  Precio  Stock
# 0  Manzanas     100     30
# 3      uvas     120     30
# 4     Peras      90     40

# %%
filtro_multiple = df[(df['Precio']>80) & (df['Stock']>30)]
print("Productos con precio mayor a 80 y stock mayor a 30:\n", filtro_multiple)
# Out:
# Productos con precio mayor a 80 y stock mayor a 30:
#    Producto  Precio  Stock
# 4    Peras      90     40

# %%
filtrado_texto = df[df['Producto'].str.contains('P')]
print("Productos que contienen la letra 'P':\n", filtrado_texto)
# Out:
# Productos que contienen la letra 'P':
#     Producto  Precio  Stock
# 2  Platanos      60     20
# 4     Peras      90     40

# %%
filtro_columnas = df[['Producto', 'Precio']]
print("Seleccionar columnas 'Produtos' y 'Precios':\n", filtro_columnas)
# Out:
# Seleccionar columnas 'Produtos' y 'Precios':
#     Producto  Precio
# 0  Manzanas     100
# 1  Naranjas      80
# 2  Platanos      60
# 3      uvas     120
# 4     Peras      90

# %%
filtro_query = df.query('Precio>80')
print("Productos con precio mayor a 80 usando query :\n", filtro_query)
# Out:
# Productos con precio mayor a 80 usando query :
#     Producto  Precio  Stock
# 0  Manzanas     100     30
# 3      uvas     120     30
# 4     Peras      90     40

# %%
filtro_isin = df[df['Producto'].isin(['Manzanas', 'uvas'])]
print("Productos que son Manzanas y Uvas:\n", filtro_isin)
# Out:
# Productos que son Manzanas y Uvas:
#     Producto  Precio  Stock
# 0  Manzanas     100     30
# 3      uvas     120     30

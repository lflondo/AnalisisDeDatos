# %%
import pandas as pd

# %%
data = {
    'Producto':['Manzanas', 'Naranjas', 'Platanos', 'Uvas', 'Peras'],
    'Precio': [100, 80, 60, 120, 90]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Producto  Precio
# 0  Manzanas     100
# 1  Naranjas      80
# 2  Platanos      60
# 3      Uvas     120
# 4     Peras      90

# %%
df.set_index('Producto', inplace=True)

# %%
print(df)
# Out:
#           Precio
# Producto
# Manzanas     100
# Naranjas      80
# Platanos      60
# Uvas         120
# Peras         90

# %%
precio_uvas = df.loc['Uvas']
print(precio_uvas)
# Out:
# Precio    120
# Name: Uvas, dtype: int64

# %%
nuevo_orden = ['Uvas', 'Manzanas', 'Naranjas', 'Peras', 'Platanos', 'Melones']
df_reindexado = df.reindex(nuevo_orden)
print(df_reindexado)
# Out:
#           Precio
# Producto
# Uvas       120.0
# Manzanas   100.0
# Naranjas    80.0
# Peras       90.0
# Platanos    60.0
# Melones      NaN

# %%
index2 = pd.Index(['Manzanas','Peras', 'melones'])
interseccion = df.index.intersection(index2)
print(interseccion)
# Out:
# Index(['Manzanas', 'Peras'], dtype='object')

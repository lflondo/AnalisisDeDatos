# %%
import numpy as np

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
#suma y resta de array (deben tener el mismo tamaño de array)
sum_ = (a+b)
print(sum_)
c = (a-b)
print(c)
# Out:
# [5 7 9]
# [-3 -3 -3]

# %%
#Escalar de array
a1=a+10
print("Escalar de A:",a1)
b1= b-10
print("Escalar de B:",b1)
# Out:
# Escalar de A: [11 12 13]
# Escalar de B: [-6 -5 -4]

# %%
#multiplicion de un array
a*b
# Out:
# array([ 4, 10, 18])

# %%
#division de array
b/a
# Out:
# array([4. , 2.5, 2. ])

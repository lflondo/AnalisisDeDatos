# %% [markdown]
# ![image.png](attachment:df3e893e-bee5-43ef-9299-320e5024ef28.png)

# %% [markdown]
# ![image.png](attachment:4d400de3-c5f1-439e-9191-25df3f92fef4.png)

# %% [markdown]
# ![image.png](attachment:176998f5-f06c-423e-b297-018908cc4f12.png)

# %%
import numpy as np

# %%
A = np.array([[3,1], [1,3]])

# %%
eigenvalues, eigenvectors = np.linalg.eig(A)
print("Autovalores:\n", eigenvalues)
print("Autovectores:\n",eingenvectors)
# Out:
# Autovalores:
#  [4. 2.]
# Autovectores:
#  [[ 0.70710678 -0.70710678]
#  [ 0.70710678  0.70710678]]
